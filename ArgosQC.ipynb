# %%
# install.packages("remotes")
unloadNamespace("ArgosQC")

remotes::install_github("ianjonsen/ArgosQC", force = TRUE)
# packageDescription("ArgosQC", fields = "Version")
# install.packages('aniMotum', repos = c('https://ocean-tracking-network.r-universe.dev', 'https://cloud.r-project.org'))
# Out:
# Using GitHub PAT from the git credential store.
#
# ...
# aniMotum (1.2-14    -> fce39776c...) [GitHub]
# units    (0.8-7     -> 1.0-0       ) [CRAN]
# s2       (1.1.7     -> 1.1.9       ) [CRAN]
# terra    (1.8-29    -> 1.8-93      ) [CRAN]
# sf       (1.0-20    -> 1.0-24      ) [CRAN]
# XML      (3.99-0.18 -> 3.99-0.20   ) [CRAN]
# Installing 5 packages: units, s2, terra, sf, XML
#   There are binary versions available but the source versions are later:
#          binary    source needs_compilation
# units     0.8-7     1.0-0              TRUE
# s2        1.1.7     1.1.9              TRUE
# terra    1.8-29    1.8-93              TRUE
# sf       1.0-20    1.0-24              TRUE
# XML   3.99-0.18 3.99-0.20              TRUE
# installing the source packages 'units', 's2', 'terra', 'sf', 'XML'
#
#
# Warning message in download.file(url, destfile, method, mode = "wb", ...):
# "downloaded length 0 != reported length 0"
# ...

# %%
install.packages("remotes")
# Out:
# package 'remotes' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\hpz2\AppData\Local\Temp\Rtmp6FJpsy\downloaded_packages

# %%
install.packages("remotes")
remotes::install_github("jmlondon/pathroutr", force = TRUE)
# Out:
# Using GitHub PAT from the git credential store.
#
# ...
# Rcpp       (1.1.0  -> 1.1.1   ) [CRAN]
# rlang      (1.1.6  -> 1.1.7   ) [CRAN]
# lifecycle  (1.0.4  -> 1.0.5   ) [CRAN]
# vctrs      (0.6.5  -> 0.7.1   ) [CRAN]
# proxy      (0.4-27 -> 0.4-29  ) [CRAN]
# wk         (NA     -> 0.9.5   ) [CRAN]
# e1071      (1.7-16 -> 1.7-17  ) [CRAN]
# units      (NA     -> 1.0-0   ) [CRAN]
# s2         (NA     -> 1.1.9   ) [CRAN]
# magrittr   (2.0.3  -> 2.0.4   ) [CRAN]
# classInt   (NA     -> 0.4-11  ) [CRAN]
# stringr    (1.5.2  -> 1.6.0   ) [CRAN]
# purrr      (1.1.0  -> 1.2.1   ) [CRAN]
# cpp11      (0.5.2  -> 0.5.3   ) [CRAN]
# tidyr      (1.3.1  -> 1.3.2   ) [CRAN]
# tibble     (3.3.0  -> 3.3.1   ) [CRAN]
# pillar     (1.11.0 -> 1.11.1  ) [CRAN]
# igraph     (NA     -> 2.2.1   ) [CRAN]
# geometries (NA     -> 0.2.5   ) [CRAN]
# sf         (NA     -> 1.0-24  ) [CRAN]
# BH         (NA     -> 1.90.0-1) [CRAN]
# tidygraph  (NA     -> 1.3.1   ) [CRAN]
# sfheaders  (NA     -> 0.4.5   ) [CRAN]
# ...

# %%
install.packages("sf", type = "binary")
install.packages("units", type = "binary")
install.packages("vctrs", type = "binary")
install.packages("igraph", type = "binary")
wk
s2
lwgeom
# Out:
#   There is a binary version available (and will be installed) but the
#   source version is later:
#    binary source
# sf 1.0-20 1.0-24
#
# package 'sf' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\hpz2\AppData\Local\Temp\Rtmp8AbJrm\downloaded_packages
#
#   There is a binary version available (and will be installed) but the
#   source version is later:
#       binary source
# units  0.8-7  1.0-0
#
# package 'units' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\hpz2\AppData\Local\Temp\Rtmp8AbJrm\downloaded_packages
#
#   There is a binary version available (and will be installed) but the
#   source version is later:
#       binary source
# vctrs  0.6.5  0.7.1
#
# package 'vctrs' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'vctrs'"
# Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# ...

# %%
library(ArgosQC)
library(pathroutr)
# packageVersion('ArgosQC') 
# wc_qc(
#   wd = ".",
#   config = "config_grey_seal_lidgard_wc.json"
# )
