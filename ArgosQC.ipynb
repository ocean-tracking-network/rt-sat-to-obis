# %%
# No compatible binary for below package. Install from source
install.packages(c("terra", "units", "dplyr"))
remotes::install_github("ianjonsen/aniMotum", force = TRUE, INSTALL_opts = "--no-multiarch")
library(aniMotum)
# Out:
#   There is a binary version available but the source version is later:
#       binary source needs_compilation
# dplyr  1.1.4  1.2.0              TRUE
#
# package 'terra' successfully unpacked and MD5 sums checked
# package 'units' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\hpz2\AppData\Local\Temp\RtmpuW6V7u\downloaded_packages
# installing the source package 'dplyr'

# %%
install.packages(c('sfnetworks', 'igraph', 'lwgeom', 'nabor'))
remotes::install_github("jmlondon/pathroutr", force = TRUE)
# Out:
# Using GitHub PAT from the git credential store.
#
# Downloading GitHub repo jmlondon/pathroutr@HEAD
# igraph (NA -> 2.2.1   ) [CRAN]
# BH     (NA -> 1.90.0-1) [CRAN]
# Skipping 1 packages ahead of CRAN: dplyr
#
# Installing 2 packages: igraph, BH
# package 'igraph' successfully unpacked and MD5 sums checked
# package 'BH' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\hpz2\AppData\Local\Temp\RtmpuW6V7u\downloaded_packages
# ── R CMD build ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ✔  checking for file 'C:\Users\hpz2\AppData\Local\Temp\RtmpuW6V7u\remotes6b142ce47160\jmlondon-pathroutr-372beed/DESCRIPTION' (355ms)
# ─  preparing 'pathroutr': (629ms)
# ✔  checking DESCRIPTION meta-information
#    Warning in as.POSIXlt.POSIXct(x, tz) :
#      unknown timezone 'America/Edmonton'
#    Warning in as.POSIXlt.POSIXct(x, tz) : unknown timezone 'GMT'
#    Warning in as.POSIXlt.POSIXct(x, tz) :
#      unknown timezone 'America/New_York'
#    Warning in as.POSIXlt.POSIXct(x, tz) : unknown timezone 'GMT'
#    Warning in as.POSIXlt.POSIXct(x, tz) :
#      unknown timezone 'America/New_York'
# ─  checking for LF line-endings in source and make files and shell scripts
# ─  checking for empty or unneeded directories
# ─  building 'pathroutr_0.2.1.tar.gz'

# %%
# Run this everytime to get the latest ArgosQC package
options(install.packages.check.source = "no")
options(pkgType = "binary")

packageDescription("ArgosQC", fields = "Version")
unloadNamespace("ArgosQC")


remotes::install_github("ianjonsen/ArgosQC", force = TRUE, INSTALL_opts = "--no-multiarch")
# Out:
# Warning message in packageDescription("ArgosQC", fields = "Version"):
# "no package 'ArgosQC' was found"
# [1] NA
# Using GitHub PAT from the git credential store.
#
# Downloading GitHub repo ianjonsen/ArgosQC@HEAD
# svglite (NA -> 2.2.2    ) [CRAN]
# XML     (NA -> 3.99-0.20) [CRAN]
# Skipping 5 packages ahead of CRAN: viridisLite, base64enc, globals, dplyr, ggplot2
#
# Installing 2 packages: svglite, XML
# package 'svglite' successfully unpacked and MD5 sums checked
# package 'XML' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\hpz2\AppData\Local\Temp\RtmpuW6V7u\downloaded_packages
# ── R CMD build ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# ✔  checking for file 'C:\Users\hpz2\AppData\Local\Temp\RtmpuW6V7u\remotes6b14d8ab4b\ianjonsen-ArgosQC-fc0783e/DESCRIPTION'
# ─  preparing 'ArgosQC': (3.3s)
# ✔  checking DESCRIPTION meta-information
# ─  checking for LF line-endings in source and make files and shell scripts (406ms)
# ─  checking for empty or unneeded directories
#    Omitted 'LazyData' from DESCRIPTION
# ─  building 'ArgosQC_0.9-14.tar.gz'

# %%
# remotes::install_github("jmlondon/pathroutr", force = TRUE, INSTALL_opts = "--no-multiarch")
remotes::install_github("ropensci/rnaturalearthhires", force = TRUE, INSTALL_opts = "--no-multiarch")
#           use remotes::install_github("ropensci/rnaturalearthhires") to install

# %% [markdown]
# ### Configurtion
# - "time.step":12,
# - "pred.int":12
# pred.int should be greater than and multiple of time.step in hours; both can be float

# %%
library(ArgosQC)
library(pathroutr)
packageVersion('ArgosQC') 
wc_qc(
  wd = ".",
  config = "config_grey_seal_lidgard_wc.json"
)
# Out:
# [1] '0.9.14'
# Downloading tag data from Wildlife Computers Data Portal...
#
# Reading tag data files...
#
# wc_pull_data() removed from the QC workflow 2 tag dataset(s) with no Locations data: .ipynbwc_pull_data() removed from the QC workflow 2 tag dataset(s) with no Locations data: 5be7810fefec720dc8d00907
#
# Building deployment metadata from WC Portal...
#
# Preparing location data for QC...
#
# Fitting QC SSM - first pass...
# Fitting QC SSM - second pass & rerouting locations off land...
# resetting map_scale = 50 because rnaturalearthhires is not installed,
#           use remotes::install_github("ropensci/rnaturalearthhires") to install
# QC'd locations estimated & rerouted...
#
# Appending QC'd locations to tag data files...
#
# Generating QC diagnostic plots...
# using map scale: 50
# Writing QC'd data files to .csv...
#
# QC workflow completed
#
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# $dropIDs
# [1] ""
#
# $wc
# $wc$Locations
# # A tibble: 21,301 × 19
#    DeploymentID DeployID    Ptt Instr Date                Type  Quality Latitude
#    <chr>        <chr>     <dbl> <chr> <dttm>              <chr> <chr>      <dbl>
#  1 65b902b53ca… 260358   260358 UT    2024-01-29 16:23:34 Argos 2           43.9
#  2 65b902b53ca… 260358   260358 UT    2024-02-16 11:59:49 Argos 1           43.8
#  3 65b902b53ca… 260358   260358 UT    2024-02-16 12:41:47 Argos 3           43.8
#  4 65b902b53ca… 260358   260358 UT    2024-02-16 12:48:19 Argos 2           43.8
#  5 65b902b53ca… 260358   260358 UT    2024-02-16 13:43:26 Argos B           43.7
#  6 65b902b53ca… 260358   260358 UT    2024-02-16 14:14:38 Argos 2           43.7
#  7 65b902b53ca… 260358   260358 UT    2024-02-16 14:20:20 Argos 3           43.7
#  8 65b902b53ca… 260358   260358 UT    2024-02-16 14:27:52 Argos 3           43.7
#  9 65b902b53ca… 260358   260358 UT    2024-02-16 14:48:05 Argos 2           43.7
# 10 65b902b53ca… 260358   260358 UT    2024-02-16 15:58:43 Argos 0           43.7
# # ℹ 21,291 more rows
# # ℹ 11 more variables: Longitude <dbl>, `Error radius` <dbl>,
# #   `Error Semi-major axis` <dbl>, `Error Semi-minor axis` <dbl>,
# #   `Error Ellipse orientation` <dbl>, Offset <lgl>,
# #   `Offset orientation` <lgl>, `GPE MSD` <lgl>, `GPE U` <lgl>, Count <lgl>,
# #   Comment <lgl>
#
# $wc$FastGPS
# # A tibble: 64 × 102
#    DeploymentID      Name  Day   Time     Count `Time Offset` LocNumber Failures
#    <chr>             <chr> <chr> <time>   <dbl>         <dbl> <lgl>     <lgl>
#  1 65b902b53caf33c4… 2603… 21-J… 03:13:31     1           -72 NA        NA
#  2 65b902b53caf33c4… 2603… 08-M… 16:43:52     3           -70 NA        NA
#  3 65b902b53caf33c4… 2603… 05-A… 21:46:05     1           -68 NA        NA
#  4 65b902b53caf33c4… 2603… 26-A… 00:44:02     1           -67 NA        NA
#  5 65b902b53caf33c4… 2603… 28-A… 05:06:20     1           -61 NA        NA
#  6 65b902b53caf33c4… 2603… 01-O… 19:44:20     1           -59 NA        NA
#  7 65b902b53caf33c4… 2603… 01-N… 02:13:44     1           -58 NA        NA
#  8 65b902b53caf33c4… 2603… 30-N… 00:13:29     1           -56 NA        NA
#  9 65b902b53caf33c4… 2603… 24-F… 00:11:52     2           -52 NA        NA
# 10 65b902b53caf33c4… 2603… 08-A… 16:48:42     1           -50 NA        NA
# # ℹ 54 more rows
# # ℹ 94 more variables: `Hauled Out` <dbl>, Satellites <dbl>, InitLat <lgl>,
# #   InitLon <lgl>, InitTime <lgl>, InitType <lgl>, Latitude <lgl>,
# #   Longitude <lgl>, Height <lgl>, `50CI` <lgl>, `95CI` <lgl>,
# #   `Bad Sats` <lgl>, R95 <lgl>, Residual <lgl>, `Time Error` <lgl>,
# #   `TWIC Power` <lgl>, `Fastloc Power` <lgl>, Noise <lgl>, `Range Bits` <dbl>,
# #   Id...28 <dbl>, Range...29 <dbl>, Signal...30 <lgl>, Doppler...31 <lgl>, …
#
# $wc$ECDHistos_SCOUT_TEMP_361A
# list()
#
# $wc$ECDHistos_SCOUT_DSA
# list()
#
# $wc$Histos
# # A tibble: 465 × 88
#    DeploymentID             DeployID    Ptt DepthSensor Source    Instr HistType
#    <chr>                    <chr>     <dbl>       <dbl> <chr>     <chr> <chr>
#  1 65b902b53caf33c4780bbfb8 260358   260358         0.5 Transmis… UT    1Percent
#  2 65b902b53caf33c4780bbfb8 260358   260358         0.5 Transmis… UT    1Percent
#  3 65b902b53caf33c4780bbfb8 260358   260358         0.5 Transmis… UT    1Percent
#  4 65b902b53caf33c4780bbfb8 260358   260358         0.5 Transmis… UT    1Percent
#  5 65b902b53caf33c4780bbfb8 260358   260358         0.5 Transmis… UT    1Percent
#  6 65b902b53caf33c4780bbfb8 260358   260358         0.5 Transmis… UT    1Percent
#  7 65b902b53caf33c4780bbfb8 260358   260358         0.5 Transmis… UT    1Percent
#  8 65b902b53caf33c4780bbfb8 260358   260358         0.5 Transmis… UT    1Percent
#  9 65b902b53caf33c4780bbfb8 260358   260358         0.5 Transmis… UT    1Percent
# 10 65b902b53caf33c4780bbfb8 260358   260358         0.5 Transmis… UT    1Percent
# # ℹ 455 more rows
# # ℹ 81 more variables: Date <dttm>, `Time Offset` <dbl>, Count <dbl>,
# #   BadTherm <lgl>, LocationQuality <lgl>, Latitude <lgl>, Longitude <lgl>,
# #   NumBins <dbl>, Sum <lgl>, Bin1 <dbl>, Bin2 <dbl>, Bin3 <dbl>, Bin4 <dbl>,
# #   Bin5 <dbl>, Bin6 <dbl>, Bin7 <dbl>, Bin8 <dbl>, Bin9 <dbl>, Bin10 <dbl>,
# #   Bin11 <dbl>, Bin12 <dbl>, Bin13 <dbl>, Bin14 <dbl>, Bin15 <dbl>,
# #   Bin16 <dbl>, Bin17 <dbl>, Bin18 <dbl>, Bin19 <dbl>, Bin20 <dbl>, …
#
# $wc$MixLayer
# list()
#
# $wc$PDTs
# list()
#
# $wc$DSA
# list()
#
# $wc$MinMaxDepth
# # A tibble: 397 × 15
#    DeploymentID            DeployID    Ptt DepthSensor Instr Date
#    <chr>                   <chr>     <dbl>       <dbl> <chr> <dttm>
#  1 65b902b53caf33c4780bbf… 260358   260358         0.5 UT    2024-02-16 00:00:00
#  2 65b902b53caf33c4780bbf… 260358   260358         0.5 UT    2024-02-17 00:00:00
#  3 65b902b53caf33c4780bbf… 260358   260358         0.5 UT    2024-02-18 00:00:00
#  4 65b902b53caf33c4780bbf… 260358   260358         0.5 UT    2024-02-19 00:00:00
#  5 65b902b53caf33c4780bbf… 260358   260358         0.5 UT    2024-02-20 00:00:00
#  6 65b902b53caf33c4780bbf… 260358   260358         0.5 UT    2024-02-21 00:00:00
#  7 65b902b53caf33c4780bbf… 260358   260358         0.5 UT    2024-02-24 00:00:00
#  8 65b902b53caf33c4780bbf… 260358   260358         0.5 UT    2024-02-25 00:00:00
#  9 65b902b53caf33c4780bbf… 260358   260358         0.5 UT    2024-02-26 00:00:00
# 10 65b902b53caf33c4780bbf… 260358   260358         0.5 UT    2024-02-28 00:00:00
# # ℹ 387 more rows
# # ℹ 9 more variables: LocationQuality <lgl>, Latitude <lgl>, Longitude <lgl>,
# #   MinDepth <dbl>, MinAccuracy <dbl>, MinSource <chr>, MaxDepth <lgl>,
# #   MaxAccuracy <lgl>, MaxSource <lgl>
#
# $wc$Haulout
# list()
#
# $wc$SST
# list()
#
#
# $meta
#               DeploymentID sattag_program                 owner tag_model
# 1 65b902b53caf33c4780bbfb8           6417 damian.lidgard@dal.ca     SPOT6
# 2 65b902ba3851990dd108907c           6417 damian.lidgard@dal.ca     SPOT6
# 3 65b902b43851990dd1089072           6417 damian.lidgard@dal.ca     SPOT6
# 4 65b902b2d1123fd50006e6c3           6417 damian.lidgard@dal.ca     SPOT6
#   tag_serial_number tag_ptt deploy_date deploy_location deploy_longitude
# 1           23U3710  260358        <NA>         unknown               NA
# 2           23U3716  260364        <NA>         unknown               NA
# 3           23U3723  260371        <NA>         unknown               NA
# 4           23U3736  260378        <NA>         unknown               NA
#   deploy_latitude         embark_date embark_longitude embark_latitude
# 1              NA 2024-02-16 22:18:38        -59.89977        43.59758
# 2              NA 2024-02-20 02:05:04        -59.85426        43.94354
# 3              NA 2024-02-07 15:30:43        -60.45840        43.52340
# 4              NA 2024-02-10 00:39:55        -60.31012        44.10732
#   common_name            species sex age_class length length_measurement
# 1   grey seal Halichoerus grypus  NA        NA     NA                 NA
# 2   grey seal Halichoerus grypus  NA        NA     NA                 NA
# 3   grey seal Halichoerus grypus  NA        NA     NA                 NA
# 4   grey seal Halichoerus grypus  NA        NA     NA                 NA
#   length_unit mass mass_measurement mass_unit       QC_start_date QC_end_date
# 1          NA   NA               NA        NA 2024-02-16 22:18:38          NA
# 2          NA   NA               NA        NA 2024-02-20 02:05:04          NA
# 3          NA   NA               NA        NA 2024-02-07 15:30:43          NA
# 4          NA   NA               NA        NA 2024-02-10 00:39:55          NA
#
# $locations_sf
# # A tibble: 4 × 2
#   DeploymentID             d_sf
#   <chr>                    <list>
# 1 65b902b2d1123fd50006e6c3 <sf [7,655 × 8]>
# 2 65b902b43851990dd1089072 <sf [6,995 × 8]>
# 3 65b902b53caf33c4780bbfb8 <sf [3,028 × 8]>
# 4 65b902ba3851990dd108907c <sf [3,555 × 8]>
#
# $fit1
# # A tibble: 4 × 5
#   id                       ssm          converged pdHess pmodel
#   <chr>                    <named list> <lgl>     <lgl>  <chr>
# 1 65b902b2d1123fd50006e6c3 <ssm [15]>   TRUE      TRUE   rw
# 2 65b902b43851990dd1089072 <ssm [15]>   TRUE      TRUE   rw
# 3 65b902b53caf33c4780bbfb8 <ssm [15]>   TRUE      TRUE   rw
# 4 65b902ba3851990dd108907c <ssm [15]>   TRUE      TRUE   rw
#
# $fit2
# # A tibble: 4 × 5
#   id                       ssm        converged pdHess pmodel
#   <chr>                    <list>     <lgl>     <lgl>  <chr>
# 1 65b902b2d1123fd50006e6c3 <ssm [16]> TRUE      TRUE   rw
# 2 65b902b43851990dd1089072 <ssm [16]> TRUE      TRUE   rw
# 3 65b902b53caf33c4780bbfb8 <ssm [16]> TRUE      TRUE   rw
# 4 65b902ba3851990dd108907c <ssm [16]> TRUE      TRUE   rw
#
# $wc_ssm
# $wc_ssm$Locations
# # A tibble: 21,236 × 25
# # Groups:   DeploymentID [4]
#    DeploymentID DeployID    Ptt Instr Date                Type  Quality Latitude
#    <chr>        <chr>     <dbl> <chr> <dttm>              <chr> <chr>      <dbl>
#  1 65b902b2d11… 260378   260378 UT    2024-02-10 00:39:55 Argos 1           44.1
#  2 65b902b2d11… 260378   260378 UT    2024-02-10 00:54:32 Argos 1           44.1
#  3 65b902b2d11… 260378   260378 UT    2024-02-10 01:31:19 Argos 3           44.1
#  4 65b902b2d11… 260378   260378 UT    2024-02-10 01:34:36 Argos 3           44.1
#  5 65b902b2d11… 260378   260378 UT    2024-02-10 01:45:46 Argos B           44.1
#  6 65b902b2d11… 260378   260378 UT    2024-02-10 02:25:05 Argos 2           44.1
#  7 65b902b2d11… 260378   260378 UT    2024-02-10 02:39:33 Argos A           44.1
#  8 65b902b2d11… 260378   260378 UT    2024-02-10 11:10:57 Argos B           44.1
#  9 65b902b2d11… 260378   260378 UT    2024-02-10 11:17:20 Argos 2           44.1
# 10 65b902b2d11… 260378   260378 UT    2024-02-10 11:23:35 Argos A           44.1
# # ℹ 21,226 more rows
# # ℹ 17 more variables: Longitude <dbl>, `Error radius` <dbl>,
# #   `Error Semi-major axis` <dbl>, `Error Semi-minor axis` <dbl>,
# #   `Error Ellipse orientation` <dbl>, Offset <lgl>,
# #   `Offset orientation` <lgl>, `GPE MSD` <lgl>, `GPE U` <lgl>, Count <lgl>,
# #   Comment <lgl>, ssm_lon <dbl>, ssm_lat <dbl>, ssm_x <dbl>, ssm_y <dbl>,
# #   ssm_x_se <dbl>, ssm_y_se <dbl>
#
# $wc_ssm$FastGPS
# # A tibble: 1 × 108
#   DeploymentID       Name  Day   Time     Count `Time Offset` LocNumber Failures
#   <chr>              <chr> <chr> <time>   <dbl>         <dbl> <lgl>     <lgl>
# 1 65b902b53caf33c47… 2603… 13-N… 07:16:38     1            NA NA        NA
# # ℹ 100 more variables: `Hauled Out` <dbl>, Satellites <dbl>, InitLat <lgl>,
# #   InitLon <lgl>, InitTime <lgl>, InitType <lgl>, Latitude <lgl>,
# #   Longitude <lgl>, Height <lgl>, `50CI` <lgl>, `95CI` <lgl>,
# #   `Bad Sats` <lgl>, R95 <lgl>, Residual <lgl>, `Time Error` <lgl>,
# #   `TWIC Power` <lgl>, `Fastloc Power` <lgl>, Noise <lgl>, `Range Bits` <dbl>,
# #   Id...28 <dbl>, Range...29 <dbl>, Signal...30 <lgl>, Doppler...31 <lgl>,
# #   CNR...32 <lgl>, Id...33 <dbl>, Range...34 <dbl>, Signal...35 <lgl>, …
#
# $wc_ssm$Histos
# # A tibble: 459 × 94
#    DeploymentID             DeployID    Ptt DepthSensor Source    Instr HistType
#    <chr>                    <chr>     <dbl>       <dbl> <chr>     <chr> <chr>
#  1 65b902b2d1123fd50006e6c3 260378   260378         0.5 Transmis… UT    1Percent
#  2 65b902b2d1123fd50006e6c3 260378   260378         0.5 Transmis… UT    1Percent
#  3 65b902b2d1123fd50006e6c3 260378   260378         0.5 Transmis… UT    1Percent
#  4 65b902b2d1123fd50006e6c3 260378   260378         0.5 Transmis… UT    1Percent
#  5 65b902b2d1123fd50006e6c3 260378   260378         0.5 Transmis… UT    1Percent
#  6 65b902b2d1123fd50006e6c3 260378   260378         0.5 Transmis… UT    1Percent
#  7 65b902b2d1123fd50006e6c3 260378   260378         0.5 Transmis… UT    1Percent
#  8 65b902b2d1123fd50006e6c3 260378   260378         0.5 Transmis… UT    1Percent
#  9 65b902b2d1123fd50006e6c3 260378   260378         0.5 Transmis… UT    1Percent
# 10 65b902b2d1123fd50006e6c3 260378   260378         0.5 Transmis… UT    1Percent
# # ℹ 449 more rows
# # ℹ 87 more variables: Date <dttm>, `Time Offset` <dbl>, Count <dbl>,
# #   BadTherm <lgl>, LocationQuality <lgl>, Latitude <lgl>, Longitude <lgl>,
# #   NumBins <dbl>, Sum <lgl>, Bin1 <dbl>, Bin2 <dbl>, Bin3 <dbl>, Bin4 <dbl>,
# #   Bin5 <dbl>, Bin6 <dbl>, Bin7 <dbl>, Bin8 <dbl>, Bin9 <dbl>, Bin10 <dbl>,
# #   Bin11 <dbl>, Bin12 <dbl>, Bin13 <dbl>, Bin14 <dbl>, Bin15 <dbl>,
# #   Bin16 <dbl>, Bin17 <dbl>, Bin18 <dbl>, Bin19 <dbl>, Bin20 <dbl>, …
#
# $wc_ssm$MinMaxDepth
# # A tibble: 391 × 21
#    DeploymentID            DeployID    Ptt DepthSensor Instr Date
#    <chr>                   <chr>     <dbl>       <dbl> <chr> <dttm>
#  1 65b902b2d1123fd50006e6… 260378   260378         0.5 UT    2024-02-11 00:00:00
#  2 65b902b2d1123fd50006e6… 260378   260378         0.5 UT    2024-02-12 00:00:00
#  3 65b902b2d1123fd50006e6… 260378   260378         0.5 UT    2024-02-13 00:00:00
#  4 65b902b2d1123fd50006e6… 260378   260378         0.5 UT    2024-02-14 00:00:00
#  5 65b902b2d1123fd50006e6… 260378   260378         0.5 UT    2024-02-15 00:00:00
#  6 65b902b2d1123fd50006e6… 260378   260378         0.5 UT    2024-02-17 00:00:00
#  7 65b902b2d1123fd50006e6… 260378   260378         0.5 UT    2024-02-18 00:00:00
#  8 65b902b2d1123fd50006e6… 260378   260378         0.5 UT    2024-02-19 00:00:00
#  9 65b902b2d1123fd50006e6… 260378   260378         0.5 UT    2024-02-20 00:00:00
# 10 65b902b2d1123fd50006e6… 260378   260378         0.5 UT    2024-02-21 00:00:00
# # ℹ 381 more rows
# # ℹ 15 more variables: LocationQuality <lgl>, Latitude <lgl>, Longitude <lgl>,
# #   MinDepth <dbl>, MinAccuracy <dbl>, MinSource <chr>, MaxDepth <lgl>,
# #   MaxAccuracy <lgl>, MaxSource <lgl>, ssm_lon <dbl>, ssm_lat <dbl>,
# #   ssm_x <dbl>, ssm_y <dbl>, ssm_x_se <dbl>, ssm_y_se <dbl>
