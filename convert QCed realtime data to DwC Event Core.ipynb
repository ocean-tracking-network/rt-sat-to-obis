# %% [markdown]
# # IMOS realtime data to DwC Event Core
#
# Plan: Convert the realtime QCed IMOS marine mammal position data to DwC, and then publish the result to the IPT.
#
# Contemporary notes from our meet w/ Ian Jonsen here: https://docs.google.com/document/d/1hibIxBbyGwa7b5-LRpnKIyjnr41EkUPKBzdUJoyAfaU/edit#heading=h.6bqw4binj5hq

# %% [markdown]
# ### Inputs / configuration parameters:
#
# * QCed data for a given campaign or project as the exported CSVs with appended position correction data as per https://github.com/ianjonsen/ArgosQC
# * credentials for IPT and
# * corresponding project ID to associate new data with
# * minimum quality hit to keep

# %%
import pandas as pd

metadata_df = pd.read_csv('input/metadata_ct180_nrt.csv')
loc_df = pd.read_csv('input/diag_ct180_nrt.csv')

# %%
metadata_df[0:10]
# Out:
#   sattag_program          device_id    ptt    body device_wmo_ref  \
# 0          ct180   ct180-156-BAT-15  14156  196997       Q9902018
# 1          ct180  ct180-172-BAT3-15  14172  153719       Q9902019
# 2          ct180   ct180-946-BAT-18  14946  221816       Q9902020
# 3          ct180   ct180-963-BAT-18  14963  221821       Q9902021
# 4          ct180  ct180-183-BAT2-20  15183  196991       Q9902022
# 5          ct180  ct180-C184-BAT-20  15184  221802       Q9902023
# 6          ct180   ct180-266-BAT-20  15266  204698       Q9902038
# 7          ct180   ct180-302-BAT-20  15302  204693       Q9902024
# 8          ct180   ct180-304-BAT-20  15304  204688       Q9902025
# 9          ct180   ct180-306-BAT-20  15306  204699       Q9902033
#
#        tag_type             common_name           species  release_longitude  \
# 0  CTD_QUOT_23A  Southern elephant seal  Mirounga leonina             70.218
# 1  CTD_QUOT_23A  Southern elephant seal  Mirounga leonina             70.218
# 2  CTD_QUOT_23A  Southern elephant seal  Mirounga leonina             70.218
# 3  CTD_QUOT_23A  Southern elephant seal  Mirounga leonina             70.218
# 4  CTD_QUOT_23A  Southern elephant seal  Mirounga leonina             70.218
# 5  CTD_QUOT_23A  Southern elephant seal  Mirounga leonina             70.218
# 6  CTD_QUOT_23A  Southern elephant seal  Mirounga leonina             70.218
# 7  CTD_QUOT_23A  Southern elephant seal  Mirounga leonina             70.218
# 8  CTD_QUOT_23A  Southern elephant seal  Mirounga leonina             70.218
# 9  CTD_QUOT_23A  Southern elephant seal  Mirounga leonina             70.218
#
#    release_latitude  ...          release_date recovery_date  age_class  sex  \
# 0          -49.3496  ...  2023-12-21T00:00:00Z           NaN        NaN    m
# 1          -49.3496  ...  2023-12-23T00:00:00Z           NaN        NaN    m
# 2          -49.3496  ...  2023-12-21T00:00:00Z           NaN        NaN    m
# 3          -49.3496  ...  2023-12-21T00:00:00Z           NaN        NaN    m
# 4          -49.3496  ...  2024-01-09T00:00:00Z           NaN        NaN    f
# 5          -49.3496  ...  2023-12-20T00:00:00Z           NaN        NaN    m
# 6          -49.3496  ...  2024-02-11T00:00:00Z           NaN        NaN    f
# 7          -49.3496  ...  2023-12-22T00:00:00Z           NaN        NaN    m
# 8          -49.3496  ...  2023-12-23T00:00:00Z           NaN        NaN    m
# 9          -49.3496  ...  2024-02-08T00:00:00Z           NaN        NaN    f
#
#   length  estimated_mass  actual_mass              state_country  \
# 0   2.36             NaN        255.5  French Overseas Territory
# 1   2.65             NaN        344.5  French Overseas Territory
# 2   3.02             NaN        577.0  French Overseas Territory
# 3   2.55             NaN        328.5  French Overseas Territory
# 4   2.15             NaN        249.5  French Overseas Territory
# 5   2.52             NaN        373.0  French Overseas Territory
# 6   2.38             NaN        250.5  French Overseas Territory
# 7   2.97             NaN        608.5  French Overseas Territory
# 8   2.53             NaN        315.5  French Overseas Territory
# 9   2.19             NaN        248.0  French Overseas Territory
#
#           qc_start_date           qc_end_date
# 0  2024-01-02T12:00:00Z  2024-01-06T18:00:00Z
# 1  2023-12-24T10:00:00Z  2024-04-01T10:00:00Z
# 2  2024-01-10T13:00:00Z  2024-03-31T07:00:00Z
# 3  2023-12-24T14:00:00Z  2024-04-01T14:00:00Z
# 4  2024-01-09T12:00:00Z  2024-04-01T18:00:00Z
# 5  2024-01-07T20:00:00Z  2024-01-13T14:00:00Z
# 6  2024-02-18T11:00:00Z  2024-04-01T11:00:00Z
# 7  2024-01-14T12:00:00Z  2024-01-15T00:00:00Z
# 8  2024-01-09T18:00:00Z  2024-04-01T18:00:00Z
# 9  2024-02-08T19:00:00Z  2024-04-01T13:00:00Z
#
# [10 rows x 21 columns]

# %% [markdown]
# ## Metadata - create events and occurrences for each row
#
# Process the metadata csv into Event Core (animal releases + tag attachments) + Occurrences (HumanObservations) + emofs for same (biological measurements are here)

# %%
metadata_df

# event entries: eventID = [body]-[release_date]
#                eventDate =  [release_date]
#                latitude = [release_latitude]
#                longitude = [release_longitude]
#                modified = current_date()
#                geodeticDatum = EPSG:4326
#                country = state_country  (error in current dataset, French Overseas Territory should be French Southern Lands)

column_map = {'release_date':'eventDate',
              'release_latitude':'decimalLatitude',
              'release_longitude':'decimalLongitude',
              'state_country':'country'}

event_df = metadata_df.rename(columns=column_map)
event_df['modified'] = pd.to_datetime('now', utc=True).round(freq='s')
# eventID is instrument serial number (body) + release datetime (eventDate)
event_df['eventID'] = event_df['body'].astype(str).str.cat(event_df['eventDate'].astype(str), sep='-')
event_df['geodeticDatum'] = 'EPSG:4326'
# Optional: truncate the extra columns from the core
event_df =  event_df[['eventID', 'eventDate', 'decimalLatitude', 'decimalLongitude', 'modified', 'geodeticDatum', 'country']]

# %%
event_df[0:5]
# Out:
#                        eventID             eventDate  decimalLatitude  \
# 0  196997-2023-12-21T00:00:00Z  2023-12-21T00:00:00Z         -49.3496
# 1  153719-2023-12-23T00:00:00Z  2023-12-23T00:00:00Z         -49.3496
# 2  221816-2023-12-21T00:00:00Z  2023-12-21T00:00:00Z         -49.3496
# 3  221821-2023-12-21T00:00:00Z  2023-12-21T00:00:00Z         -49.3496
# 4  196991-2024-01-09T00:00:00Z  2024-01-09T00:00:00Z         -49.3496
#
#    decimalLongitude                  modified geodeticDatum  \
# 0            70.218 2024-09-09 19:49:19+00:00     EPSG:4326
# 1            70.218 2024-09-09 19:49:19+00:00     EPSG:4326
# 2            70.218 2024-09-09 19:49:19+00:00     EPSG:4326
# 3            70.218 2024-09-09 19:49:19+00:00     EPSG:4326
# 4            70.218 2024-09-09 19:49:19+00:00     EPSG:4326
#
#                      country
# 0  French Overseas Territory
# 1  French Overseas Territory
# 2  French Overseas Territory
# 3  French Overseas Territory
# 4  French Overseas Territory

# %%
# EMOFs to harvest
# for the release events
# instrument manufacturer and model  (SMRU + [tag type])
# PTT
# device id
# WMO ref

# %%
# occ ext. entries:    occurrenceID = [body]-[release_date]
#                      species = [species]
#                      sex = [sex]
#                      eventID = [body]-[release_date]
#                      organismID = [body]-[release_date]

occ_column_map = {'release_date':'eventDate',
                  'species':'scientificName'}
occ_df = metadata_df.rename(columns=occ_column_map)
occ_df['occurrenceID'] = occ_df['body'].astype(str).str.cat(occ_df['eventDate'].astype(str), sep='-')
occ_df['eventID'] = occ_df['body'].astype(str).str.cat(occ_df['eventDate'].astype(str), sep='-')
occ_df['organismID'] = occ_df['body'].astype(str).str.cat(occ_df['eventDate'].astype(str), sep='-')
occ_df['basisOfRecord'] = 'HumanObservation'
occ_df = occ_df[['occurrenceID', 'organismID','eventID', 'sex', 'scientificName', 'basisOfRecord']]

# %%
occ_df[0:5]
# Out:
#                   occurrenceID                   organismID  \
# 0  196997-2023-12-21T00:00:00Z  196997-2023-12-21T00:00:00Z
# 1  153719-2023-12-23T00:00:00Z  153719-2023-12-23T00:00:00Z
# 2  221816-2023-12-21T00:00:00Z  221816-2023-12-21T00:00:00Z
# 3  221821-2023-12-21T00:00:00Z  221821-2023-12-21T00:00:00Z
# 4  196991-2024-01-09T00:00:00Z  196991-2024-01-09T00:00:00Z
#
#                        eventID sex    scientificName     basisOfRecord
# 0  196997-2023-12-21T00:00:00Z   m  Mirounga leonina  HumanObservation
# 1  153719-2023-12-23T00:00:00Z   m  Mirounga leonina  HumanObservation
# 2  221816-2023-12-21T00:00:00Z   m  Mirounga leonina  HumanObservation
# 3  221821-2023-12-21T00:00:00Z   m  Mirounga leonina  HumanObservation
# 4  196991-2024-01-09T00:00:00Z   f  Mirounga leonina  HumanObservation

# %%
# EMOFs to harvest
# for the occurrences:
# sex
# length
# weight

# %%
# Create event and occurrence entries from the locations data file
# 
# Event entries:  eventID = organismID + date_detected
#                 latitude = ssm_lat if exists else lat
#                 longitude = ssm_lon if exists else lon
#                 eventDate = d_date
#                 geodeticDatum = EPSG:4326
#                 coordinateUncertaintyInMeters = max(ssm_x_se, ssm_y_se)  -- 1 SE or 2 SE?
#                 

# add the relevant columns to loc_df from metadata_df to create organismID
loc_df = loc_df.merge(metadata_df[['device_id', 'body', 'release_date', 'species']], 
                      how='left', left_on='ref', right_on='device_id')

# %%
# combine the organismID + the detection date into the eventID
loc_df['eventID'] = loc_df['body'].astype(str).str.cat(loc_df[['release_date', 'd_date']], sep='-')

# %%
# Check: is this correct to do in all cases?
# where there has been no correction made (corrected positions = NA, 
#       then use the raw position data
loc_df['decimalLatitude'] = loc_df['ssm_lat'].fillna(loc_df['lat'])
loc_df['decimalLongitude'] = loc_df['ssm_lon'].fillna(loc_df['lon'])
loc_df['eventDate'] = loc_df['d_date']
loc_df['modified'] = pd.to_datetime('now', utc=True).round(freq='s') 

# constant
loc_df['geodeticDatum'] = 'EPSG:4326'

# Ian's got his ssm_x and ssm_y in km, not in m
loc_df['coordinateUncertaintyInMeters'] = loc_df[['ssm_x_se', 'ssm_y_se']].max(axis=1) * 1000

# Where there are multiple hits for a given time step (many satellites have opinions on position at once), 

loc_df = loc_df.sort_values(['ref', 'd_date', 'lq'], ascending=False)
# drop all but the best of the location qualities
loc_df = loc_df.drop_duplicates(subset=['ref','d_date'], keep='first', inplace=False)

# %%
loc_df['lq'].unique()
# Out:
# array([-2, -1,  0, -9,  1,  2,  3])

# %%
# fallback - where coordinateUncertaintyInMeters is still null (un-QCed), 
# let's do something with the class of fix from Argos. set a lookup table as in the ATN example?

# Ian recommends - dan costa, accuracy of argos locations at sea pinnipeds
# in that article they compared GPS to Argos locations.
# https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0008677

# While this paper recommends different regimes per species due to differences in surfacing behaviour, 
# we don't have that kind of broad data in real-time land.

# So we take their recommendations for marine mammals here, and maybe we'd leave the door open to use a non-mammal error chart
# for non-airbreathers

# Other methodologies have thrown out the A and B quality hits altogther. 
# I'm not opposed to doing that but i'll confirm it with the SME beforehand
# because the QC algorithm is re-positioning the bad hits for us already.
# and if they didn't throw them out, we may not want to either.

# 68th percentile location error distances from Costa et al, in metres
# old LQ designations - CLS moved to a Kalman-filtered location set in ~2011
# error ellipses are now de riguer - semimajor and 
# semiminor ellipse axis/orientation to quantify uncertainty
# So we could harvest those first.

error_table = {3:490,
               2:1010,
               1:1200,
               0:4180,
               -1:6190,
               -2:10280,
               -9:10280} # TODO : What is the corresponding code to -9 LQ? 
                         # AniMotum thinks it's a class B
missing_errors = loc_df['coordinateUncertaintyInMeters'].isna()
loc_df.loc[missing_errors, 'coordinateUncertaintyInMeters'] = loc_df.loc[missing_errors, 'lq'].map(error_table)

# %%
loc_df['coordinateUncertaintyInMeters'].describe()
# Out:
# count    29384.000000
# mean      4784.129207
# std       3539.984849
# min          3.893000
# 25%       1814.351250
# 50%       3387.965500
# 75%       7831.693500
# max      22061.320000
# Name: coordinateUncertaintyInMeters, dtype: float64

# %%
loc_df['modified']
# Out:
# 9204   2024-09-09 19:49:22+00:00
# 9203   2024-09-09 19:49:22+00:00
# 9202   2024-09-09 19:49:22+00:00
# 9200   2024-09-09 19:49:22+00:00
# 9199   2024-09-09 19:49:22+00:00
#                   ...
# 4      2024-09-09 19:49:22+00:00
# 3      2024-09-09 19:49:22+00:00
# 2      2024-09-09 19:49:22+00:00
# 1      2024-09-09 19:49:22+00:00
# 0      2024-09-09 19:49:22+00:00
# Name: modified, Length: 29384, dtype: datetime64[ns, UTC]

# %%
# Select the columns and append to the event_df

event_df = pd.concat([event_df, loc_df[['eventID', 'eventDate', 'decimalLatitude', 'decimalLongitude', 'modified','geodeticDatum', 'coordinateUncertaintyInMeters']]])

# %%
event_df
# Out:
#                                              eventID             eventDate  \
# 0                        196997-2023-12-21T00:00:00Z  2023-12-21T00:00:00Z
# 1                        153719-2023-12-23T00:00:00Z  2023-12-23T00:00:00Z
# 2                        221816-2023-12-21T00:00:00Z  2023-12-21T00:00:00Z
# 3                        221821-2023-12-21T00:00:00Z  2023-12-21T00:00:00Z
# 4                        196991-2024-01-09T00:00:00Z  2024-01-09T00:00:00Z
# ..                                               ...                   ...
# 4   196997-2023-12-21T00:00:00Z-2023-12-21T18:30:36Z  2023-12-21T18:30:36Z
# 3   196997-2023-12-21T00:00:00Z-2023-12-21T18:29:15Z  2023-12-21T18:29:15Z
# 2   196997-2023-12-21T00:00:00Z-2023-12-21T16:49:47Z  2023-12-21T16:49:47Z
# 1   196997-2023-12-21T00:00:00Z-2023-12-21T16:49:17Z  2023-12-21T16:49:17Z
# 0   196997-2023-12-21T00:00:00Z-2023-12-21T16:46:13Z  2023-12-21T16:46:13Z
#
#     decimalLatitude  decimalLongitude                  modified geodeticDatum  \
# 0         -49.34960          70.21800 2024-09-09 19:49:19+00:00     EPSG:4326
# 1         -49.34960          70.21800 2024-09-09 19:49:19+00:00     EPSG:4326
# 2         -49.34960          70.21800 2024-09-09 19:49:19+00:00     EPSG:4326
# 3         -49.34960          70.21800 2024-09-09 19:49:19+00:00     EPSG:4326
# 4         -49.34960          70.21800 2024-09-09 19:49:19+00:00     EPSG:4326
# ..              ...               ...                       ...           ...
# 4         -49.35232          70.22904 2024-09-09 19:49:22+00:00     EPSG:4326
# 3         -49.35449          70.22380 2024-09-09 19:49:22+00:00     EPSG:4326
# 2         -49.35438          70.20778 2024-09-09 19:49:22+00:00     EPSG:4326
# 1         -49.35458          70.20625 2024-09-09 19:49:22+00:00     EPSG:4326
# 0         -49.35023          70.22467 2024-09-09 19:49:22+00:00     EPSG:4326
#
#                       country  coordinateUncertaintyInMeters
# 0   French Overseas Territory                            NaN
# 1   French Overseas Territory                            NaN
# 2   French Overseas Territory                            NaN
# 3   French Overseas Territory                            NaN
# 4   French Overseas Territory                            NaN
# ..                        ...                            ...
# 4                         NaN                         4180.0
# 3                         NaN                          490.0
# 2                         NaN                          490.0
# 1                         NaN                         1010.0
# 0                         NaN                         1200.0
#
# [29409 rows x 8 columns]

# %%
# Occurrence entries: occurrenceID = eventID
#                     eventID = eventID
#                     species = species
#                     organismID = body + release_date

loc_df['occurrenceID'] = loc_df['eventID']
loc_df['organismID'] =  loc_df['body'].astype(str).str.cat(loc_df['release_date'].astype(str), sep='-')

# %%
# Decimate to first each hour per animal. Acoustics would also use per-receiver location, argos and sat won't need that.
dets_df = loc_df
dets_df['scientificName'] = dets_df['species']
dets_df['basisOfRecord'] = 'MachineObservation'
dets_df['Date'] = pd.to_datetime(dets_df['d_date']).dt.date
dets_df['hr'] = pd.to_datetime(dets_df['d_date']).dt.hour
dets_df['binsize'] = dets_df.groupby(['organismID', 'Date', 'hr']).size().reset_index(name='binsize')['binsize']
dets_df.drop_duplicates(subset=['organismID','Date', 'hr'], keep='first', inplace=True)
dets_df.drop('hr', axis=1, inplace=True)
dets_df
# Out:
#                     ref     ptt                d_date  lq       lat       lon  \
# 9204  ct180-C184-BAT-20  221802  2024-03-15T17:26:21Z  -2 -50.22177  67.71829
# 9203  ct180-C184-BAT-20  221802  2024-03-15T07:13:38Z  -2 -52.70706  69.24513
# 9202  ct180-C184-BAT-20  221802  2024-03-14T16:49:33Z  -2 -56.07488  71.43531
# 9199  ct180-C184-BAT-20  221802  2024-03-13T05:49:06Z  -2 -50.12263  72.08237
# 9198  ct180-C184-BAT-20  221802  2024-03-12T19:39:55Z  -2 -50.11433  72.53114
# ...                 ...     ...                   ...  ..       ...       ...
# 11     ct180-156-BAT-15  196997  2023-12-21T21:03:26Z   2 -49.36094  70.22439
# 10     ct180-156-BAT-15  196997  2023-12-21T20:13:51Z   2 -49.36058  70.22365
# 7      ct180-156-BAT-15  196997  2023-12-21T19:26:17Z   2 -49.35243  70.23752
# 5      ct180-156-BAT-15  196997  2023-12-21T18:33:18Z   1 -49.34763  70.22586
# 2      ct180-156-BAT-15  196997  2023-12-21T16:49:47Z   3 -49.35438  70.20778
#
#        alt_lat   alt_lon  n_mess  n_mess_120  ...             eventDate  \
# 9204 -50.22177  67.71829       1           0  ...  2024-03-15T17:26:21Z
# 9203 -47.82350  81.83484       1           0  ...  2024-03-15T07:13:38Z
# 9202 -48.75767  82.61287       2           0  ...  2024-03-14T16:49:33Z
# 9199 -50.12263  72.08237       2           0  ...  2024-03-13T05:49:06Z
# 9198 -50.11433  72.53114       2           0  ...  2024-03-12T19:39:55Z
# ...        ...       ...     ...         ...  ...                   ...
# 11   -49.36094  70.22439       5           0  ...  2023-12-21T21:03:26Z
# 10   -49.36058  70.22365       4           0  ...  2023-12-21T20:13:51Z
# 7    -49.35243  70.23752       9           0  ...  2023-12-21T19:26:17Z
# 5    -49.34763  70.22586       7           0  ...  2023-12-21T18:33:18Z
# 2    -49.35438  70.20778       6           0  ...  2023-12-21T16:49:47Z
#
#                       modified  geodeticDatum  coordinateUncertaintyInMeters  \
# 9204 2024-09-09 19:49:22+00:00      EPSG:4326                        10280.0
# 9203 2024-09-09 19:49:22+00:00      EPSG:4326                        10280.0
# 9202 2024-09-09 19:49:22+00:00      EPSG:4326                        10280.0
# 9199 2024-09-09 19:49:22+00:00      EPSG:4326                        10280.0
# 9198 2024-09-09 19:49:22+00:00      EPSG:4326                        10280.0
# ...                        ...            ...                            ...
# 11   2024-09-09 19:49:22+00:00      EPSG:4326                         1010.0
# 10   2024-09-09 19:49:22+00:00      EPSG:4326                         1010.0
# 7    2024-09-09 19:49:22+00:00      EPSG:4326                         1010.0
# 5    2024-09-09 19:49:22+00:00      EPSG:4326                         1200.0
# 2    2024-09-09 19:49:22+00:00      EPSG:4326                          490.0
#
#                                           occurrenceID  \
# 9204  221802-2023-12-20T00:00:00Z-2024-03-15T17:26:21Z
# 9203  221802-2023-12-20T00:00:00Z-2024-03-15T07:13:38Z
# 9202  221802-2023-12-20T00:00:00Z-2024-03-14T16:49:33Z
# 9199  221802-2023-12-20T00:00:00Z-2024-03-13T05:49:06Z
# 9198  221802-2023-12-20T00:00:00Z-2024-03-12T19:39:55Z
# ...                                                ...
# 11    196997-2023-12-21T00:00:00Z-2023-12-21T21:03:26Z
# 10    196997-2023-12-21T00:00:00Z-2023-12-21T20:13:51Z
# 7     196997-2023-12-21T00:00:00Z-2023-12-21T19:26:17Z
# 5     196997-2023-12-21T00:00:00Z-2023-12-21T18:33:18Z
# 2     196997-2023-12-21T00:00:00Z-2023-12-21T16:49:47Z
#
#                        organismID    scientificName       basisOfRecord  \
# 9204  221802-2023-12-20T00:00:00Z  Mirounga leonina  MachineObservation
# 9203  221802-2023-12-20T00:00:00Z  Mirounga leonina  MachineObservation
# 9202  221802-2023-12-20T00:00:00Z  Mirounga leonina  MachineObservation
# 9199  221802-2023-12-20T00:00:00Z  Mirounga leonina  MachineObservation
# 9198  221802-2023-12-20T00:00:00Z  Mirounga leonina  MachineObservation
# ...                           ...               ...                 ...
# 11    196997-2023-12-21T00:00:00Z  Mirounga leonina  MachineObservation
# 10    196997-2023-12-21T00:00:00Z  Mirounga leonina  MachineObservation
# 7     196997-2023-12-21T00:00:00Z  Mirounga leonina  MachineObservation
# 5     196997-2023-12-21T00:00:00Z  Mirounga leonina  MachineObservation
# 2     196997-2023-12-21T00:00:00Z  Mirounga leonina  MachineObservation
#
#             Date  binsize
# 9204  2024-03-15      2.0
# 9203  2024-03-15      1.0
# 9202  2024-03-14      2.0
# 9199  2024-03-13      3.0
# 9198  2024-03-12      1.0
# ...          ...      ...
# 11    2023-12-21      1.0
# 10    2023-12-21      1.0
# 7     2023-12-21      3.0
# 5     2023-12-21      1.0
# 2     2023-12-21      1.0
#
# [17570 rows x 52 columns]

# %%
dets_df['binsize'].describe()
# Out:
# count    9515.000000
# mean        1.669049
# std         0.891345
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         6.000000
# Name: binsize, dtype: float64

# %%
dets_df['dataGeneralizations'] = dets_df['binsize'].apply(lambda x: 'subsampled by hour, first of {} record(s)'.format(x))

# %%
occ_df = pd.concat([occ_df, dets_df[['occurrenceID', 'eventID', 'scientificName', 'organismID', 'basisOfRecord']]])

# %%
# flesh out the occurrence taxonomic entries with kingdom, phylum, class, order, family
import pyworms

lookup_dict = {}
for name in occ_df['scientificName'].unique():
    resp = pyworms.aphiaRecordsByMatchNames(name)
    if len(resp[0]) == 0:
        print('\nNo match for name "{}"'.format(name))
        continue
    elif len(resp[0]) > 1:
        print('\nMultiple matches for name "{}"'.format(name))
        pprint.pprint(resp[0], indent=4)
        continue
    else:
        worms = resp[0][0]
        lookup_dict[name]={'scientificName': name,
                           'scientificNameID': worms['lsid'],
                           'taxonRank': worms['rank'],
                           'kingdom': worms['kingdom'],
                           'phylum': worms['phylum'],
                           'class': worms['class'],
                           'order': worms['order'],
                           'family': worms['family']}
        
lookup_df = pd.DataFrame.from_dict(lookup_dict, orient='index')

# %%
lookup_df
# Out:
#                     scientificName                           scientificNameID  \
# Mirounga leonina  Mirounga leonina  urn:lsid:marinespecies.org:taxname:231413
#
#                  taxonRank   kingdom    phylum     class      order    family
# Mirounga leonina   Species  Animalia  Chordata  Mammalia  Carnivora  Phocidae

# %%
occ_df = occ_df.join(lookup_df, how='left', on='scientificName', rsuffix='_worms')

# %%
occ_df
# Out:
#                                         occurrenceID  \
# 0                        196997-2023-12-21T00:00:00Z
# 1                        153719-2023-12-23T00:00:00Z
# 2                        221816-2023-12-21T00:00:00Z
# 3                        221821-2023-12-21T00:00:00Z
# 4                        196991-2024-01-09T00:00:00Z
# ..                                               ...
# 11  196997-2023-12-21T00:00:00Z-2023-12-21T21:03:26Z
# 10  196997-2023-12-21T00:00:00Z-2023-12-21T20:13:51Z
# 7   196997-2023-12-21T00:00:00Z-2023-12-21T19:26:17Z
# 5   196997-2023-12-21T00:00:00Z-2023-12-21T18:33:18Z
# 2   196997-2023-12-21T00:00:00Z-2023-12-21T16:49:47Z
#
#                      organismID  \
# 0   196997-2023-12-21T00:00:00Z
# 1   153719-2023-12-23T00:00:00Z
# 2   221816-2023-12-21T00:00:00Z
# 3   221821-2023-12-21T00:00:00Z
# 4   196991-2024-01-09T00:00:00Z
# ..                          ...
# 11  196997-2023-12-21T00:00:00Z
# 10  196997-2023-12-21T00:00:00Z
# 7   196997-2023-12-21T00:00:00Z
# 5   196997-2023-12-21T00:00:00Z
# 2   196997-2023-12-21T00:00:00Z
#
#                                              eventID  sex    scientificName  \
# 0                        196997-2023-12-21T00:00:00Z    m  Mirounga leonina
# 1                        153719-2023-12-23T00:00:00Z    m  Mirounga leonina
# 2                        221816-2023-12-21T00:00:00Z    m  Mirounga leonina
# 3                        221821-2023-12-21T00:00:00Z    m  Mirounga leonina
# 4                        196991-2024-01-09T00:00:00Z    f  Mirounga leonina
# ..                                               ...  ...               ...
# 11  196997-2023-12-21T00:00:00Z-2023-12-21T21:03:26Z  NaN  Mirounga leonina
# 10  196997-2023-12-21T00:00:00Z-2023-12-21T20:13:51Z  NaN  Mirounga leonina
# 7   196997-2023-12-21T00:00:00Z-2023-12-21T19:26:17Z  NaN  Mirounga leonina
# 5   196997-2023-12-21T00:00:00Z-2023-12-21T18:33:18Z  NaN  Mirounga leonina
# 2   196997-2023-12-21T00:00:00Z-2023-12-21T16:49:47Z  NaN  Mirounga leonina
#
#          basisOfRecord scientificName_worms  \
# 0     HumanObservation     Mirounga leonina
# 1     HumanObservation     Mirounga leonina
# 2     HumanObservation     Mirounga leonina
# 3     HumanObservation     Mirounga leonina
# 4     HumanObservation     Mirounga leonina
# ..                 ...                  ...
# 11  MachineObservation     Mirounga leonina
# 10  MachineObservation     Mirounga leonina
# 7   MachineObservation     Mirounga leonina
# 5   MachineObservation     Mirounga leonina
# 2   MachineObservation     Mirounga leonina
#
#                              scientificNameID taxonRank   kingdom    phylum  \
# 0   urn:lsid:marinespecies.org:taxname:231413   Species  Animalia  Chordata
# 1   urn:lsid:marinespecies.org:taxname:231413   Species  Animalia  Chordata
# 2   urn:lsid:marinespecies.org:taxname:231413   Species  Animalia  Chordata
# 3   urn:lsid:marinespecies.org:taxname:231413   Species  Animalia  Chordata
# 4   urn:lsid:marinespecies.org:taxname:231413   Species  Animalia  Chordata
# ..                                        ...       ...       ...       ...
# 11  urn:lsid:marinespecies.org:taxname:231413   Species  Animalia  Chordata
# 10  urn:lsid:marinespecies.org:taxname:231413   Species  Animalia  Chordata
# 7   urn:lsid:marinespecies.org:taxname:231413   Species  Animalia  Chordata
# 5   urn:lsid:marinespecies.org:taxname:231413   Species  Animalia  Chordata
# 2   urn:lsid:marinespecies.org:taxname:231413   Species  Animalia  Chordata
#
#        class      order    family
# 0   Mammalia  Carnivora  Phocidae
# 1   Mammalia  Carnivora  Phocidae
# 2   Mammalia  Carnivora  Phocidae
# 3   Mammalia  Carnivora  Phocidae
# 4   Mammalia  Carnivora  Phocidae
# ..       ...        ...       ...
# 11  Mammalia  Carnivora  Phocidae
# 10  Mammalia  Carnivora  Phocidae
# 7   Mammalia  Carnivora  Phocidae
# 5   Mammalia  Carnivora  Phocidae
# 2   Mammalia  Carnivora  Phocidae
#
# [17595 rows x 14 columns]

# %%
occ_df['organismID'].unique()
# Out:
# array(['196997-2023-12-21T00:00:00Z', '153719-2023-12-23T00:00:00Z',
#        '221816-2023-12-21T00:00:00Z', '221821-2023-12-21T00:00:00Z',
#        '196991-2024-01-09T00:00:00Z', '221802-2023-12-20T00:00:00Z',
#        '204698-2024-02-11T00:00:00Z', '204693-2023-12-22T00:00:00Z',
#        '204688-2023-12-23T00:00:00Z', '204699-2024-02-08T00:00:00Z',
#        '204703-2024-02-09T00:00:00Z', '204702-2023-12-20T00:00:00Z',
#        '204701-2023-12-22T00:00:00Z', '204717-2024-02-09T00:00:00Z',
#        '204704-2024-01-26T00:00:00Z', '204739-2023-12-23T00:00:00Z',
#        '204732-2024-02-09T00:00:00Z', '204738-2023-12-31T00:00:00Z',
#        '221824-2024-02-11T00:00:00Z', '221820-2023-12-19T00:00:00Z',
#        '221798-2023-12-20T00:00:00Z', '221799-2024-02-11T00:00:00Z',
#        '221801-2024-01-26T00:00:00Z', '221814-2023-12-19T00:00:00Z',
#        '221810-2023-12-21T00:00:00Z'], dtype=object)

# %%
# Any EMOFs to harvest from detection occurrences?
# 
#

# %%
# Push them out to files and an archive:

occ_df.to_csv('output/occurrences.csv', date_format='%Y-%m-%dT%H:%M:%S')
event_df.to_csv('output/events.csv', date_format='%Y-%m-%dT%H:%M:%S')
# emof_df.to_csv('output/emof.csv', date_format='%Y-%m-%dT%H:%M:%S')

# %%
# Zip and ship to an IPT

# Either via a form fill-in, or via depositing the archive on the IPT's filesystem?

# TODO: Try the form-fill first - use the OTN IPT workflows from ipython-utilities
# import requests  # session with the forms themselves
# import selenium  # or pick-n-click

# %% [markdown]
# ### Debugging cells:

# %%
# throwing out all but max lq will help us de-duplicate these same-time-same-tag hits?
loc_df['lq'].describe()
# Out:
# count    17570.000000
# mean        -1.409505
# std          1.080688
# min         -9.000000
# 25%         -2.000000
# 50%         -2.000000
# 75%         -1.000000
# max          3.000000
# Name: lq, dtype: float64
